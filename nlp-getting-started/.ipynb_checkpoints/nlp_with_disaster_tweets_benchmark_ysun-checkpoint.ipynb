# %% [markdown]
# # Real or Not? NLP with Disaster Tweets - LR, SVM, RF, GBM
#
# [Predict which Tweets are about real disasters and which ones are not](https://www.kaggle.com/c/nlp-getting-started)
#
# _Y. Sun_

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sys
sys.path.insert(1, '/home/ys/github/kaggle/')

from mypreprocessor import unslang

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_train = pd.read_csv('train.csv')
df_train.tail(3)
# Out:
#          id keyword location  \
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# ### Characters cleaning

# %%
import os
import re
import string

def remove_url(text):
    """Remove URL in the text."""
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)

def remove_html(text):
    """Remove HTML tags in the text."""
    html = re.compile(r'<.*?>')
    return html.sub(r'', text)

def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_punctuation(text):
    """Remove punctuations in text."""
    # replacing the punctuations with no space, 
    # which in effect deletes the punctuation marks 
    table = str.maketrans('', '', string.punctuation)
    # return the text stripped of punctuation marks
    return text.translate(table)

# %%
df_train['text'] = df_train['text'].apply(remove_url)
df_train['text'] = df_train['text'].apply(remove_html)
df_train['text'] = df_train['text'].apply(remove_emoji)
df_train['text'] = df_train['text'].apply(remove_punctuation)
df_train.tail(3)
# Out:
#          id keyword location  \
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 7610              M194 0104 UTC5km S of Volcano Hawaii        1
# 7611  Police investigating after an ebike collided w...       1
# 7612  The Latest More Homes Razed by Northern Califo...       1

# %% [markdown]
# ### Words cleaning (normalization)

# %%
from spellchecker import SpellChecker
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

def spelling(text):
    """Correct spelling mistakes in the text."""
    corrected_text = []
    spell = SpellChecker()
    misspelled_words = spell.unknown(text.split())
    for word in text.split():
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    return " ".join(corrected_text)

def stemming(text):    
    """Stem each word based on word root in the given text."""
    SBStemmer = SnowballStemmer('english')
    text = [SBStemmer.stem(word) for word in text.split()]
    return " ".join(text)

def lemmatizing(text):
    pass

def remove_stopwords(text):
    """Remove stopwards in text."""
    sw = stopwords.words('english')
    # remove the stop words and lowercase the selected words
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    # joining the list of words with space separator
    return " ".join(text)

# %%
#df_train['text'] = df_train['text'].apply(spelling)
df_train['text'] = df_train['text'].apply(stemming)
df_train['text'] = df_train['text'].apply(remove_stopwords)
df_train['text'] = df_train['text'].apply(unslang)
df_train.tail(3)
# Out:
#          id keyword location  \
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 7610                    m194 0104 utc5km volcano hawaii       1
# 7611  polic investig ebik collid car littl portug eb...       1
# 7612  latest home raze northern california wildfir a...       1

# %% [markdown]
# #### _* compare stemming and lemmatizing_

# %%
import spacy # !python -m spacy download en_core_web_sm
import nltk

# load spacy's English language models
en_nlp = spacy.load('en_core_web_sm')
# instantiate nltk's Porter stemmer
stemmer = nltk.stem.PorterStemmer()

# define function to compare lemmatization in spacy with stemming in nltk
def compare_normalization(doc):
    # tokenize document in spacy
    doc_spacy = en_nlp(doc)
    # print lemmas found by spacy
    print('Lemmatization:')
    print([token.lemma_ for token in doc_spacy if token.lemma_ != '-PRON-'])
    # print tokens found by Porter stemmer
    print('Stemming')
    print([stemmer.stem(token.norm_.lower()) for token in doc_spacy])

compare_normalization("Our meeting was worse than yesterday, "
                       "I'm scared of meeting the clients.")
# Out:
# Lemmatization:
# ['meeting', 'be', 'bad', 'than', 'yesterday', ',', 'be', 'scared', 'of', 'meet', 'the', 'client', '.']
# Stemming
# ['our', 'meet', 'wa', 'wors', 'than', 'yesterday', ',', 'i', 'am', 'scare', 'of', 'meet', 'the', 'client', '.']

# %% [markdown]
# #### _* bag-of-words_

# %% [markdown]
# - Tokenization
# - Vocabulary building
# - Encoding (one-hot)
# - n-Grams

# %% [markdown]
# #### _* CountVectorizer wth lemmatization_

# %%
# regexp used in CountVectorizer
regexp = re.compile('(?u)\\b\\w\\w+\\b')

# load spacy language model and save old (default) tokenizer
nlp = spacy.load('en_core_web_sm')
old_tokenizer = nlp.tokenizer
# replace the tokenizer with the preceding regexp
# nlp <-- old_tokenizer.tokens_from_list (new in v2.0)
nlp.tokenizer = lambda string: old_tokenizer.tokens_from_list(regexp.findall(string))

# create a custom tokenizer using the spacy document processing pipeline
# (now using our own tokennizer)
def custom_tokenizer(document):
    doc_spacy = nlp(document, disable=["tagger", "parser"])
    return [token.lemma_ for token in doc_spacy]

# define a count vectorizer with the custom tokenizer
lemma_vect = CountVectorizer(tokenizer=custom_tokenizer, min_df=5)

# transform X_train_text using CountVectorizer with lemmatization
X_train_lemma = lemma_vect.fit_transform(X_train_text)
print('X_train_lemma.shape: {}'.format(X_train_lemma.shape))

# %% [markdown]
# ## Machine learning model

# %% [markdown]
# The advantages of building pipelines:
#
# - Reduce the preprocessing and classification process;
# - Avoid information leakage from validation datasets during cross-validation (cross_val_score or GridSearchCV).

# %%
import mglearn
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.pipeline import make_pipeline

# %%
X_train_text, X_val_text, y_train, y_val = train_test_split(
    df_train['text'], df_train['target'], test_size=0.2, random_state=42)

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
pipe = make_pipeline(CountVectorizer(min_df=5), LogisticRegression(max_iter=500))
scores = cross_val_score(pipe, X_train_text, y_train, scoring='f1')
print('Cross-validation of f1-score:', scores)
print('Mean cross-validation f1-score: {:.2f}'.format(np.mean(scores)))
# Out:
# Cross-validation of f1-score: [0.72783505 0.72871287 0.74823054 0.71576763 0.74170854]
# Mean cross-validation f1-score: 0.73

# %%
param_grid = {'countvectorizer__ngram_range': [(1, 1), (1, 2), (1, 3)], 
              'logisticregression__C': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(pipe, param_grid, scoring='f1', n_jobs=-1)
grid.fit(X_train_text, y_train)

print('Best cross-validation f1-score: {:.2f}'.format(grid.best_score_))
print('F1-score of validation data: {:.2f}'.format(grid.score(X_val_text, y_val)))
print('Confusion matrix:\n', confusion_matrix(y_val, grid.predict(X_val_text)))
print(classification_report(y_val, grid.predict(X_val_text), labels=grid.best_estimator_.classes_))

# %%
vect = grid.best_estimator_.named_steps['countvectorizer']
feature_names = np.array(vect.get_feature_names())

print('Number of features: {}'.format(len(feature_names)))
print('First 100 features:\n{}'.format(feature_names[:100]))
print('Every 100 features:\n{}'.format(feature_names[::100]))

print('Weighs of the most important features:')
coef = grid.best_estimator_.named_steps['logisticregression'].coef_
mglearn.tools.visualize_coefficients(coef, feature_names, n_top_features=40)
bottom, top = plt.ylim()
# Out:
# Number of features: 2073
# First 100 features:
# ['05' '06' '10' '100' '1000' '101' '11' '11yearold' '12' '12000' '13' '14'
#  '15' '16' '16yr' '17' '18' '19' '1945' '1980' '1st' '20' '2011' '2013'
#  '2014' '2015' '21' '22' '24' '25' '26' '2nd' '30' '300' '300w' '31' '320'
#  '33' '3g' '40' '4000' '4wd' '4x4' '50' '500' '53inch' '5km' '60' '600'
#  '70' '70th' '90' '911' 'aba' 'abandon' 'abc' 'abl' 'ablaz' 'absolut'
#  'abstorm' 'abus' 'access' 'accid' 'accord' 'account' 'accus' 'acr'
#  'across' 'act' 'action' 'activ' 'actual' 'ad' 'add' 'admit' 'adult'
#  'advanc' 'advisori' 'af' 'affect' 'afghan' 'afghanistan' 'africa'
#  'afternoon' 'aftershock' 'age' 'ago' 'agre' 'ah' 'ahead' 'aid' 'aim'
#  'aint' 'air' 'aircraft' 'airlin' 'airplan' 'airport' 'aka' 'alabama']
# Every 100 features:
# ['05' 'alarm' 'bank' 'brown' 'cold' 'decid' 'econom' 'feat' 'glass' 'host'
#  'kerricktri' 'lower' 'mood' 'organ' 'prepared' 'repatri' 'senat' 'spend'
#  'temper' 'tv' 'whole']
# Weighs of the most important features:

# %%
plt.matshow(grid.cv_results_['mean_test_score'].reshape(3, 5).T, 
            vmin=0, cmap='viridis') 
plt.xlabel('countvectorizer__ngram_range')
plt.ylabel('logisticregression__C')
plt.xticks(range(len(param_grid['countvectorizer__ngram_range'])), 
           param_grid['countvectorizer__ngram_range'])
plt.yticks(range(len(param_grid['logisticregression__C'])), 
           param_grid['logisticregression__C'])
plt.colorbar()
plt.show()

print('Best parameters: ', grid.best_params_)
print('Best estimator: ', grid.best_estimator_)
# Out:
# Best parameters:  {'countvectorizer__ngram_range': (1, 2), 'logisticregression__C': 0.1}
# Best estimator:  Pipeline(memory=None,
#          steps=[('countvectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=5,
#                                  ngram_range=(1, 2), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('logisticregression',
#                  LogisticRegression(C=0.1, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=500,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
vect = grid.best_estimator_.named_steps['countvectorizer']
feature_names = np.array(vect.get_feature_names())

print('Number of features: {}'.format(len(feature_names)))
print('First 100 features:\n{}'.format(feature_names[:100]))
print('Every 100 features:\n{}'.format(feature_names[::100]))

# weights of features
coef = grid.best_estimator_.named_steps['logisticregression'].coef_
mglearn.tools.visualize_coefficients(coef, feature_names, n_top_features=40)
bottom, top = plt.ylim()

# find 2-gram feaures
mask = np.array([len(feature.split(' ')) for feature in feature_names]) == 2
# visualize only 2-gram features
mglearn.tools.visualize_coefficients(coef.ravel()[mask], 
                                     feature_names[mask], n_top_features=40)
plt.ylim(bottom, top)
# Out:
# Number of features: 2827
# First 100 features:
# ['05' '06' '10' '100' '1000' '101' '11' '11yearold' '11yearold boy' '12'
#  '12000' '12000 nigerian' '13' '14' '15' '15 saudi' '16' '16yr' '16yr old'
#  '17' '18' '19' '1945' '1980' '1980 prebreak' '1st' '20' '2011' '2013'
#  '2014' '2015' '2015 australia' '2015 prebreak' '21' '22' '24' '25' '26'
#  '2nd' '30' '30 fire' '300' '300w' '300w curv' '31' '320' '320 ir' '33'
#  '33 hollywood' '3g' '3g whole' '40' '40 famili' '4000' '4000 syrian'
#  '4wd' '4x4' '4x4 offroad' '50' '500' '53inch' '53inch 300w' '5km'
#  '5km volcano' '60' '600' '70' '70 year' '70th' '70th anniversari' '90'
#  '911' 'aba' 'aba woman' 'abandon' 'abandon aircraft' 'abc' 'abc news'
#  'abl' 'ablaz' 'absolut' 'abstorm' 'abus' 'access' 'accid' 'accid expert'
#  'accid man' 'accord' 'account' 'accus' 'acr' 'across' 'act' 'action'
#  'action year' 'activ' 'actual' 'ad' 'ad video' 'add']
# Every 100 features:
# ['05' 'admit' 'appear' 'bedroom' 'broke' 'chicagoarea gay' 'countri'
#  'derail villag' 'earth' 'eye' 'flood ur' 'goe' 'hobbit' 'insid' 'laden'
#  'look like' 'met' 'nation forest' 'order' 'plot' 'radio' 'rip' 'send'
#  'son' 'sue' 'togeth' 'unconfirm' 'wealth' 'you ûªv']
# Weighs of the most important features:
# Weighs of the most important features with 2-gram:
# (-0.7137676452420358, 1.1595421450179533)

# %%
df_test = pd.read_csv('test.csv')
df_sub = pd.read_csv('sample_submission.csv')

df_sub['target'] = grid.predict(df_test['text'])
df_sub.to_csv('submission.csv', index=False)
df_sub.tail(3)
# Out:
#          id  target
# 3260  10868       0
# 3261  10874       0
# 3262  10875       0

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
pipe = make_pipeline(TfidfVectorizer(ngram_range=(1, 1), min_df=5, norm=None), SVC())
scores = cross_val_score(pipe, X_train_text, y_train, scoring='f1')
print('Cross-validation of scores:', scores)
print('Mean of cross-validation scores: {:.2f}'.format(np.mean(scores)))
# Out:
# Cross-validation of f1-score: [0.72586016 0.75211864 0.74840085 0.70358306 0.74364407]
# Mean cross-validation f1-score: 0.73

# %%
param_grid = {'svc__C': [0.001, 0.01, 0.1, 1, 10, 100], 
              'svc__gamma': ['scale', 'auto']}
grid = GridSearchCV(pipe, param_grid=param_grid, scoring='f1', n_jobs=-1)
grid.fit(X_train_text, y_train)

print('Best cross-validation f1-score: {:.2f}'.format(grid.best_score_))
print('F1-score of validation data: {:.2f}'.format(grid.score(X_val_text, y_val)))
print('Confusion matrix:\n', confusion_matrix(y_val, grid.predict(X_val_text)))
# Out:
# Best cross-validation f1-score: 0.80
# F1-score of validation data: 0.80
# Confusion matrix:
#  [[784  90]
#  [212 437]]

# %%
# get vectorizer in a grid-searched pipeline
vect = grid.best_estimator_.named_steps['tfidfvectorizer']
# get feature names
feature_names = np.array(vect.get_feature_names())

print('Number of features: {}'.format(len(feature_names)))
print('First 50 features:\n{}'.format(feature_names[:50]))
print('Every 100 features:\n{}'.format(feature_names[::100]))

# transform the training datsets
X_train = vect.transform(X_train_text)
# find maximm value for each of the features over the datasets
max_value = X_train.max(axis=0).toarray().ravel()
sorted_by_tfidf = max_value.argsort()

print('Features with lowest tfidf:\n{}'.format(
    feature_names[sorted_by_tfidf[:20]]))
print('Features with highest tfidf:\n{}'.format(
    feature_names[sorted_by_tfidf[-20:]]))

sorted_by_idf = np.argsort(vect.idf_)
print('Features with lowest idf (less important):\n{}'.format(
    feature_names[sorted_by_idf[:100]]))
# Out:
# Number of features: 2073
# First 50 features:
# ['05' '06' '10' '100' '1000' '101' '11' '11yearold' '12' '12000' '13' '14'
#  '15' '16' '16yr' '17' '18' '19' '1945' '1980' '1st' '20' '2011' '2013'
#  '2014' '2015' '21' '22' '24' '25' '26' '2nd' '30' '300' '300w' '31' '320'
#  '33' '3g' '40' '4000' '4wd' '4x4' '50' '500' '53inch' '5km' '60' '600'
#  '70']
# Every 100 features:
# ['05' 'alarm' 'bank' 'brown' 'cold' 'decid' 'econom' 'feat' 'glass' 'host'
#  'kerricktri' 'lower' 'mood' 'organ' 'prepared' 'repatri' 'senat' 'spend'
#  'temper' 'tv' 'whole']
# Features with lowest tfidf:
# ['come' 'scream' 'death' 'drown' 'deton' 'hijack' 'full' 'last' 'mani'
#  'weapon' 'wave' 'die' 'flame' 'collid' 'anoth' 'catastroph' 'hot' 'photo'
#  'northern' 'right']
# Features with highest tfidf:
# ['insur' 'yeah' 'beach' 'pain' 'gt' 'pray' 'bag' 'test' 'court' 'fuck'
#  'hill' 'navi' 'gtgt' 'ar' 'shoe' 'issu' 'check' 'bus' 'bestnaijamad'
#  'wreck']
# Features with lowest idf (less important):
# ['like' 'fire' 'get' 'im' 'amp' 'bomb' 'via' 'new' 'peopl' 'news' 'go'
#  'dont' 'one' 'video' 'burn' 'kill' 'time' 'us' 'emerg' 'flood' 'build'
#  'bodi' 'say' 'year' 'crash' 'look' 'attack' 'fatal' 'disast' 'home' 'day'
#  'would' 'come' 'make' 'evacu' 'train' 'see' 'still' 'california' 'watch'
#  'know' 'scream' 'want' 'live' 'love' 'suicid' 'back' 'ûª' 'death' 'polic'
#  'caus' 'world' 'car' 'derail' 'famili' 'collaps' 'got' 'storm' 'first'
#  'whi' 'man' 'bag' 'cant' 'youtub' 'work' 'today' 'nuclear' 'take' 'drown'
#  'destroy' 'think' 'let' 'war' 'two' 'deton' 'rt' 'life' 'fear' 'need'
#  'dead' 'hijack' 'full' 'accid' 'good' 'report' 'may' 'use' 'help'
#  'obliter' 'hiroshima' 'last' 'feel' 'onli' 'wreck' 'way' 'mani' 'murder'
#  'servic' 'weapon' 'wildfir']

# %%
plt.matshow(grid.cv_results_['mean_test_score'].reshape(6, 2).T,
            vmin=0, cmap='viridis') 
plt.xlabel('svc__C')
plt.ylabel('svc__gamma')
plt.xticks(range(len(param_grid['svc__C'])), 
           param_grid['svc__C'])
plt.yticks(range(len(param_grid['svc__gamma'])), 
           param_grid['svc__gamma'])
plt.colorbar()
plt.show()

print('Best paramters:', grid.best_params_)
# Out:
# Best paramters: {'svc__C': 1, 'svc__gamma': 'scale'}

# %%
# extract scores from grid_search
scores = grid.cv_results_['mean_test_score'].reshape(6, 2).T
# visualize heat map
heatmap = mglearn.tools.heatmap(
    scores, xlabel='svc__C', ylabel='svc__gamma', cmap='viridis', fmt='%.3f', 
    xticklabels=param_grid['svc__C'], 
    yticklabels=param_grid['svc__gamma'])
plt.colorbar(heatmap)
plt.show()

print('Best parameters: ', grid.best_params_)
print('Best estimator: ', grid.best_estimator_)
# Out:
# Best parameters:  {'svc__C': 1, 'svc__gamma': 'scale'}
# Best estimator:  Pipeline(memory=None,
#          steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=5, ngram_range=(1, 1), norm=None,
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('svc',
#                  SVC(C=1, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1,
#                      probability=False, random_state=None, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
df_test = pd.read_csv('test.csv')
df_sub = pd.read_csv('sample_submission.csv')

df_sub['target'] = grid.predict(df_test['text'])
df_sub.to_csv('submission.csv', index=False)
df_sub.tail(3)
# Out:
#          id  target
# 3260  10868       0
# 3261  10874       0
# 3262  10875       0

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
pipe = make_pipeline(TfidfVectorizer(min_df=5, norm=None), 
                     RandomForestClassifier(random_state=42))
scores = cross_val_score(pipe, X_train_text, y_train, scoring='f1')
print('Cross-validation of scores:', scores)
print('Mean of cross-validation scores: {:.2f}'.format(np.mean(scores)))
# Out:
# Cross-validation of scores: [0.7159309  0.73345936 0.7322298  0.70658683 0.73875598]
# Mean of cross-validation scores: 0.73

# %%
param_grid = {'tfidfvectorizer__ngram_range': [(1, 1), (1, 2), (1, 3)], 
              'randomforestclassifier__max_features': [1, 2, 3]}
grid = GridSearchCV(pipe, param_grid=param_grid, scoring='f1', n_jobs=-1)
grid.fit(X_train_text, y_train)

print('Best cross-validation f1-score: {:.2f}'.format(grid.best_score_))
print('F1-score of validation data: {:.2f}'.format(grid.score(X_val_text, y_val)))
print('Confusion matrix:\n', confusion_matrix(y_val, grid.predict(X_val_text)))
# Out:
# Best cross-validation f1-score: 0.52
# F1-score of validation data: 0.91
# Confusion matrix:
#  [[853  21]
#  [ 93 556]]

# %%
scores = grid.cv_results_['mean_test_score'].reshape(3, 3).T
heatmap = mglearn.tools.heatmap(scores, 
                                xlabel='tfidfvectorizer__ngram_range', 
                                ylabel='randomforestclassifier__max_features', cmap='viridis', fmt='%.3f', 
                                xticklabels=param_grid['tfidfvectorizer__ngram_range'], 
                                yticklabels=param_grid['randomforestclassifier__max_features'])
plt.colorbar(heatmap)
plt.show()

print('Best parameters: ', grid.best_params_)
print('Best estimator: ', grid.best_estimator_)
# Out:
# Best parameters:  {'randomforestclassifier__max_features': 3, 'tfidfvectorizer__ngram_range': (1, 1)}
# Best estimator:  Pipeline(memory=None,
#          steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=5, ngram_range=(1, 1), norm=None,
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features=3,
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=42,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
df_test = pd.read_csv('test.csv')
df_sub = pd.read_csv('sample_submission.csv')

df_sub['target'] = grid.predict(df_test['text'])
df_sub.to_csv('submission.csv', index=False)
df_sub.tail(3)
# Out:
#          id  target
# 3260  10868       1
# 3261  10874       1
# 3262  10875       0

# %% [markdown]
# ### GBM

# %% [markdown]
# The present implementations of gradient boosting algrithm include AdaBoost, XGBoost, LightGBM and CatBoost. Here, Xgboost is tested.

# %%
# params = {
#     'max_depth': list(range(5, 11)),
#     'learning_rate': list(np.arange(0.05, 0.30, 0.05)),
#     'gamma': list(np.arange(0.01, 0.06, 0.01)),
#     'min_child_weight': list(range(1, 6)),
    
#     # fixed params
#     'n_estimators' : [1500],
#     'n_jobs': [4],
#     'objective': ['binary:logistic'],
#     'eval_metric' : ['logloss'],
#     'random_state': [42]
# }

# model = XGBClassifier(tree_method='gpu_hist')
# cv = GridSearchCV(model, params, cv=5, n_jobs=4, scoring='roc_auc')

# cv.fit(X_train, y_train)

# %%
from xgboost import XGBClassifier, plot_importance

vect = TfidfVectorizer(min_df=5)
X_train = vect.fit_transform(X_train_text)
X_val = vect.transform(X_val_text)

model = XGBClassifier(n_estimators=200, 
                      learning_rate=0.2, 
                      max_depth=6, 
                      min_child_weight=2, 
                      colsample_bytree=0.7, 
                      subsample=0.75, 
                      objective='binary:logistic', 
                      eval_metric=["auc", "logloss", "error"], 
                      early_stopping_rounds=20)

eval_set=[(X_train, y_train), (X_val, y_val)]
model.fit(X_train, y_train, early_stopping_rounds=20, 
          eval_metric=['auc', 'error', 'logloss'], eval_set=eval_set, verbose=True)

y_val_pred = model.predict(X_val)
print('Accuracy: %.2f %%' % (accuracy_score(y_val, y_val_pred) * 100))
print('F1-score: {:.2f}'.format(f1_score(y_val, y_val_pred)))
print('Confusion matrix: \n', confusion_matrix(y_val, y_val_pred))
# Out:
# [0]	validation_0-auc:0.599699	validation_0-error:0.351067	validation_0-logloss:0.672934	validation_1-auc:0.593408	validation_1-error:0.350624	validation_1-logloss:0.673772
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.618836	validation_0-error:0.334811	validation_0-logloss:0.658466	validation_1-auc:0.619341	validation_1-error:0.336179	validation_1-logloss:0.659227
# [2]	validation_0-auc:0.645219	validation_0-error:0.315435	validation_0-logloss:0.647159	validation_1-auc:0.643984	validation_1-error:0.32042	validation_1-logloss:0.648164
# [3]	validation_0-auc:0.658008	validation_0-error:0.307718	validation_0-logloss:0.638007	validation_1-auc:0.652653	validation_1-error:0.313198	validation_1-logloss:0.639945
# [4]	validation_0-auc:0.688226	validation_0-error:0.301149	validation_0-logloss:0.629971	validation_1-auc:0.676024	validation_1-error:0.308601	validation_1-logloss:0.633125
# [5]	validation_0-auc:0.706355	validation_0-error:0.295566	validation_0-logloss:0.622691	validation_1-auc:0.69723	validation_1-error:0.306632	validation_1-logloss:0.626341
# [6]	validation_0-auc:0.719964	validation_0-error:0.297537	validation_0-logloss:0.616468	validation_1-auc:0.711166	validation_1-error:0.309258	validation_1-logloss:0.620329
# [7]	validation_0-auc:0.735082	validation_0-error:0.294253	validation_0-logloss:0.609797	validation_1-auc:0.722407	validation_1-error:0.301379	validation_1-logloss:0.61474
# [8]	validation_0-auc:0.74411	validation_0-error:0.298686	validation_0-logloss:0.604237	validation_1-auc:0.729089	validation_1-error:0.304662	validation_1-logloss:0.610224
# [9]	validation_0-auc:0.754292	validation_0-error:0.290805	validation_0-logloss:0.599363	validation_1-auc:0.734801	validation_1-error:0.297439	validation_1-logloss:0.606087
# [10]	validation_0-auc:0.7591	validation_0-error:0.286207	validation_0-logloss:0.594722	validation_1-auc:0.737752	validation_1-error:0.294156	validation_1-logloss:0.602473
# [11]	validation_0-auc:0.770209	validation_0-error:0.280788	validation_0-logloss:0.589607	validation_1-auc:0.742617	validation_1-error:0.286934	validation_1-logloss:0.598345
# [12]	validation_0-auc:0.776836	validation_0-error:0.268473	validation_0-logloss:0.584705	validation_1-auc:0.748571	validation_1-error:0.28759	validation_1-logloss:0.594916
# [13]	validation_0-auc:0.782748	validation_0-error:0.26601	validation_0-logloss:0.580381	validation_1-auc:0.756792	validation_1-error:0.283651	validation_1-logloss:0.590672
# [14]	validation_0-auc:0.792215	validation_0-error:0.261576	validation_0-logloss:0.576311	validation_1-auc:0.759127	validation_1-error:0.282337	validation_1-logloss:0.589203
# [15]	validation_0-auc:0.795115	validation_0-error:0.255337	validation_0-logloss:0.572461	validation_1-auc:0.76402	validation_1-error:0.277085	validation_1-logloss:0.585907
# [16]	validation_0-auc:0.799938	validation_0-error:0.250246	validation_0-logloss:0.56884	validation_1-auc:0.767974	validation_1-error:0.274458	validation_1-logloss:0.582885
# [17]	validation_0-auc:0.807874	validation_0-error:0.249261	validation_0-logloss:0.565264	validation_1-auc:0.77512	validation_1-error:0.274458	validation_1-logloss:0.580532
# [18]	validation_0-auc:0.811065	validation_0-error:0.248112	validation_0-logloss:0.561649	validation_1-auc:0.777901	validation_1-error:0.270519	validation_1-logloss:0.578185
# [19]	validation_0-auc:0.813947	validation_0-error:0.244335	validation_0-logloss:0.558174	validation_1-auc:0.783798	validation_1-error:0.269862	validation_1-logloss:0.574248
# [20]	validation_0-auc:0.817721	validation_0-error:0.237931	validation_0-logloss:0.555207	validation_1-auc:0.787625	validation_1-error:0.269206	validation_1-logloss:0.571968
# [21]	validation_0-auc:0.820686	validation_0-error:0.236453	validation_0-logloss:0.551873	validation_1-auc:0.79178	validation_1-error:0.269862	validation_1-logloss:0.568598
# [22]	validation_0-auc:0.82492	validation_0-error:0.23087	validation_0-logloss:0.549002	validation_1-auc:0.792441	validation_1-error:0.263296	validation_1-logloss:0.567074
# [23]	validation_0-auc:0.830114	validation_0-error:0.234154	validation_0-logloss:0.546109	validation_1-auc:0.797193	validation_1-error:0.26067	validation_1-logloss:0.564557
# [24]	validation_0-auc:0.833853	validation_0-error:0.23202	validation_0-logloss:0.542832	validation_1-auc:0.79598	validation_1-error:0.2587	validation_1-logloss:0.563087
# [25]	validation_0-auc:0.834254	validation_0-error:0.231363	validation_0-logloss:0.539646	validation_1-auc:0.792861	validation_1-error:0.26067	validation_1-logloss:0.561094
# [26]	validation_0-auc:0.837686	validation_0-error:0.231363	validation_0-logloss:0.537219	validation_1-auc:0.79256	validation_1-error:0.25673	validation_1-logloss:0.56021
# [27]	validation_0-auc:0.83856	validation_0-error:0.231199	validation_0-logloss:0.534535	validation_1-auc:0.7928	validation_1-error:0.259357	validation_1-logloss:0.558343
# [28]	validation_0-auc:0.838818	validation_0-error:0.230706	validation_0-logloss:0.531933	validation_1-auc:0.793097	validation_1-error:0.258043	validation_1-logloss:0.556086
# [29]	validation_0-auc:0.840677	validation_0-error:0.228243	validation_0-logloss:0.529158	validation_1-auc:0.793075	validation_1-error:0.257387	validation_1-logloss:0.554616
# [30]	validation_0-auc:0.843154	validation_0-error:0.226601	validation_0-logloss:0.526432	validation_1-auc:0.795923	validation_1-error:0.257387	validation_1-logloss:0.553171
# [31]	validation_0-auc:0.84438	validation_0-error:0.222824	validation_0-logloss:0.524169	validation_1-auc:0.795946	validation_1-error:0.252134	validation_1-logloss:0.551918
# [32]	validation_0-auc:0.84619	validation_0-error:0.221675	validation_0-logloss:0.521694	validation_1-auc:0.797005	validation_1-error:0.251477	validation_1-logloss:0.550098
# [33]	validation_0-auc:0.847944	validation_0-error:0.222496	validation_0-logloss:0.519261	validation_1-auc:0.799161	validation_1-error:0.254104	validation_1-logloss:0.547626
# [34]	validation_0-auc:0.848975	validation_0-error:0.22266	validation_0-logloss:0.51697	validation_1-auc:0.800098	validation_1-error:0.255417	validation_1-logloss:0.545903
# [35]	validation_0-auc:0.849754	validation_0-error:0.221839	validation_0-logloss:0.514774	validation_1-auc:0.80247	validation_1-error:0.25476	validation_1-logloss:0.543956
# [36]	validation_0-auc:0.852078	validation_0-error:0.219869	validation_0-logloss:0.512634	validation_1-auc:0.803767	validation_1-error:0.253447	validation_1-logloss:0.542593
# [37]	validation_0-auc:0.854087	validation_0-error:0.219869	validation_0-logloss:0.510799	validation_1-auc:0.806287	validation_1-error:0.254104	validation_1-logloss:0.541061
# [38]	validation_0-auc:0.854764	validation_0-error:0.217734	validation_0-logloss:0.50867	validation_1-auc:0.808821	validation_1-error:0.250821	validation_1-logloss:0.538589
# [39]	validation_0-auc:0.857195	validation_0-error:0.217734	validation_0-logloss:0.506595	validation_1-auc:0.812717	validation_1-error:0.250821	validation_1-logloss:0.536833
# [40]	validation_0-auc:0.858951	validation_0-error:0.213793	validation_0-logloss:0.504586	validation_1-auc:0.813368	validation_1-error:0.246225	validation_1-logloss:0.535499
# [41]	validation_0-auc:0.860814	validation_0-error:0.2133	validation_0-logloss:0.502765	validation_1-auc:0.815265	validation_1-error:0.246225	validation_1-logloss:0.533584
# [42]	validation_0-auc:0.862201	validation_0-error:0.210673	validation_0-logloss:0.501059	validation_1-auc:0.815273	validation_1-error:0.245568	validation_1-logloss:0.533265
# [43]	validation_0-auc:0.863069	validation_0-error:0.211002	validation_0-logloss:0.499248	validation_1-auc:0.814726	validation_1-error:0.244911	validation_1-logloss:0.532741
# [44]	validation_0-auc:0.864344	validation_0-error:0.209688	validation_0-logloss:0.497401	validation_1-auc:0.815589	validation_1-error:0.243598	validation_1-logloss:0.531197
# [45]	validation_0-auc:0.864701	validation_0-error:0.209031	validation_0-logloss:0.495479	validation_1-auc:0.816303	validation_1-error:0.244255	validation_1-logloss:0.529866
# [46]	validation_0-auc:0.865928	validation_0-error:0.206897	validation_0-logloss:0.493879	validation_1-auc:0.816786	validation_1-error:0.243598	validation_1-logloss:0.528587
# [47]	validation_0-auc:0.86792	validation_0-error:0.206076	validation_0-logloss:0.492049	validation_1-auc:0.816785	validation_1-error:0.242285	validation_1-logloss:0.527783
# [48]	validation_0-auc:0.869758	validation_0-error:0.204105	validation_0-logloss:0.490224	validation_1-auc:0.817527	validation_1-error:0.240972	validation_1-logloss:0.527379
# [49]	validation_0-auc:0.870657	validation_0-error:0.201806	validation_0-logloss:0.488468	validation_1-auc:0.815657	validation_1-error:0.244911	validation_1-logloss:0.527666
# [50]	validation_0-auc:0.871535	validation_0-error:0.199507	validation_0-logloss:0.486819	validation_1-auc:0.815276	validation_1-error:0.241628	validation_1-logloss:0.526768
# [51]	validation_0-auc:0.872185	validation_0-error:0.197537	validation_0-logloss:0.485243	validation_1-auc:0.814689	validation_1-error:0.240972	validation_1-logloss:0.526322
# [52]	validation_0-auc:0.872566	validation_0-error:0.197865	validation_0-logloss:0.483626	validation_1-auc:0.815786	validation_1-error:0.238345	validation_1-logloss:0.524759
# [53]	validation_0-auc:0.872912	validation_0-error:0.200164	validation_0-logloss:0.481954	validation_1-auc:0.816708	validation_1-error:0.238345	validation_1-logloss:0.523316
# [54]	validation_0-auc:0.874412	validation_0-error:0.199507	validation_0-logloss:0.48019	validation_1-auc:0.81624	validation_1-error:0.236376	validation_1-logloss:0.522554
# [55]	validation_0-auc:0.875012	validation_0-error:0.19803	validation_0-logloss:0.478516	validation_1-auc:0.816644	validation_1-error:0.239002	validation_1-logloss:0.521847
# [56]	validation_0-auc:0.87594	validation_0-error:0.196059	validation_0-logloss:0.477063	validation_1-auc:0.816188	validation_1-error:0.238345	validation_1-logloss:0.521652
# [57]	validation_0-auc:0.87702	validation_0-error:0.196059	validation_0-logloss:0.475527	validation_1-auc:0.816539	validation_1-error:0.239002	validation_1-logloss:0.520775
# [58]	validation_0-auc:0.87803	validation_0-error:0.195895	validation_0-logloss:0.474063	validation_1-auc:0.817482	validation_1-error:0.238345	validation_1-logloss:0.519756
# [59]	validation_0-auc:0.878916	validation_0-error:0.194417	validation_0-logloss:0.472716	validation_1-auc:0.817901	validation_1-error:0.237689	validation_1-logloss:0.518859
# [60]	validation_0-auc:0.879084	validation_0-error:0.194417	validation_0-logloss:0.471347	validation_1-auc:0.817039	validation_1-error:0.237689	validation_1-logloss:0.518348
# [61]	validation_0-auc:0.879976	validation_0-error:0.193268	validation_0-logloss:0.469866	validation_1-auc:0.818913	validation_1-error:0.237032	validation_1-logloss:0.51659
# [62]	validation_0-auc:0.880394	validation_0-error:0.192118	validation_0-logloss:0.468396	validation_1-auc:0.818719	validation_1-error:0.237032	validation_1-logloss:0.516145
# [63]	validation_0-auc:0.881087	validation_0-error:0.192118	validation_0-logloss:0.467141	validation_1-auc:0.819517	validation_1-error:0.238345	validation_1-logloss:0.515354
# [64]	validation_0-auc:0.882172	validation_0-error:0.191297	validation_0-logloss:0.465908	validation_1-auc:0.819693	validation_1-error:0.239002	validation_1-logloss:0.515195
# [65]	validation_0-auc:0.882956	validation_0-error:0.191133	validation_0-logloss:0.464514	validation_1-auc:0.819185	validation_1-error:0.239002	validation_1-logloss:0.515197
# [66]	validation_0-auc:0.883768	validation_0-error:0.18867	validation_0-logloss:0.463018	validation_1-auc:0.820095	validation_1-error:0.237689	validation_1-logloss:0.514316
# [67]	validation_0-auc:0.883947	validation_0-error:0.188506	validation_0-logloss:0.461527	validation_1-auc:0.820907	validation_1-error:0.236376	validation_1-logloss:0.513512
# [68]	validation_0-auc:0.885195	validation_0-error:0.188177	validation_0-logloss:0.460294	validation_1-auc:0.822089	validation_1-error:0.239002	validation_1-logloss:0.512326
# [69]	validation_0-auc:0.886909	validation_0-error:0.187685	validation_0-logloss:0.458899	validation_1-auc:0.822212	validation_1-error:0.237689	validation_1-logloss:0.511695
# [70]	validation_0-auc:0.887402	validation_0-error:0.187192	validation_0-logloss:0.457453	validation_1-auc:0.822021	validation_1-error:0.240972	validation_1-logloss:0.510991
# [71]	validation_0-auc:0.888415	validation_0-error:0.187192	validation_0-logloss:0.456097	validation_1-auc:0.82226	validation_1-error:0.240972	validation_1-logloss:0.510318
# [72]	validation_0-auc:0.889243	validation_0-error:0.184236	validation_0-logloss:0.45465	validation_1-auc:0.821664	validation_1-error:0.241628	validation_1-logloss:0.510291
# [73]	validation_0-auc:0.88963	validation_0-error:0.183908	validation_0-logloss:0.453575	validation_1-auc:0.821699	validation_1-error:0.242942	validation_1-logloss:0.509863
# [74]	validation_0-auc:0.890141	validation_0-error:0.184893	validation_0-logloss:0.452494	validation_1-auc:0.82215	validation_1-error:0.242285	validation_1-logloss:0.509205
# [75]	validation_0-auc:0.891189	validation_0-error:0.183908	validation_0-logloss:0.45128	validation_1-auc:0.82274	validation_1-error:0.243598	validation_1-logloss:0.508638
# [76]	validation_0-auc:0.891503	validation_0-error:0.184401	validation_0-logloss:0.450074	validation_1-auc:0.822568	validation_1-error:0.240315	validation_1-logloss:0.508341
# [77]	validation_0-auc:0.892259	validation_0-error:0.183415	validation_0-logloss:0.448951	validation_1-auc:0.822371	validation_1-error:0.240315	validation_1-logloss:0.507969
# [78]	validation_0-auc:0.893538	validation_0-error:0.182923	validation_0-logloss:0.447799	validation_1-auc:0.823222	validation_1-error:0.239002	validation_1-logloss:0.507175
# [79]	validation_0-auc:0.894302	validation_0-error:0.181445	validation_0-logloss:0.446744	validation_1-auc:0.823125	validation_1-error:0.240315	validation_1-logloss:0.507129
# [80]	validation_0-auc:0.894613	validation_0-error:0.179639	validation_0-logloss:0.445445	validation_1-auc:0.8238	validation_1-error:0.237689	validation_1-logloss:0.50632
# [81]	validation_0-auc:0.895809	validation_0-error:0.179639	validation_0-logloss:0.444068	validation_1-auc:0.823909	validation_1-error:0.237032	validation_1-logloss:0.505871
# [82]	validation_0-auc:0.896167	validation_0-error:0.177997	validation_0-logloss:0.443	validation_1-auc:0.82528	validation_1-error:0.236376	validation_1-logloss:0.504514
# [83]	validation_0-auc:0.896842	validation_0-error:0.176683	validation_0-logloss:0.441895	validation_1-auc:0.826098	validation_1-error:0.237032	validation_1-logloss:0.503772
# [84]	validation_0-auc:0.897056	validation_0-error:0.177011	validation_0-logloss:0.440803	validation_1-auc:0.826045	validation_1-error:0.234406	validation_1-logloss:0.503253
# [85]	validation_0-auc:0.89728	validation_0-error:0.176519	validation_0-logloss:0.439719	validation_1-auc:0.82646	validation_1-error:0.231123	validation_1-logloss:0.502374
# [86]	validation_0-auc:0.898129	validation_0-error:0.176026	validation_0-logloss:0.438689	validation_1-auc:0.826775	validation_1-error:0.22981	validation_1-logloss:0.501958
# [87]	validation_0-auc:0.898328	validation_0-error:0.174384	validation_0-logloss:0.437716	validation_1-auc:0.827511	validation_1-error:0.228496	validation_1-logloss:0.501498
# [88]	validation_0-auc:0.898299	validation_0-error:0.174384	validation_0-logloss:0.436695	validation_1-auc:0.827147	validation_1-error:0.230466	validation_1-logloss:0.501206
# [89]	validation_0-auc:0.898703	validation_0-error:0.171921	validation_0-logloss:0.435528	validation_1-auc:0.826739	validation_1-error:0.231779	validation_1-logloss:0.501213
# [90]	validation_0-auc:0.899314	validation_0-error:0.171429	validation_0-logloss:0.434681	validation_1-auc:0.827053	validation_1-error:0.231779	validation_1-logloss:0.501121
# [91]	validation_0-auc:0.900144	validation_0-error:0.170936	validation_0-logloss:0.433588	validation_1-auc:0.826639	validation_1-error:0.231123	validation_1-logloss:0.501168
# [92]	validation_0-auc:0.900204	validation_0-error:0.172742	validation_0-logloss:0.432697	validation_1-auc:0.826418	validation_1-error:0.22981	validation_1-logloss:0.500975
# [93]	validation_0-auc:0.900564	validation_0-error:0.17225	validation_0-logloss:0.431694	validation_1-auc:0.825763	validation_1-error:0.230466	validation_1-logloss:0.501235
# [94]	validation_0-auc:0.901254	validation_0-error:0.171593	validation_0-logloss:0.43074	validation_1-auc:0.826206	validation_1-error:0.22981	validation_1-logloss:0.500559
# [95]	validation_0-auc:0.901648	validation_0-error:0.171264	validation_0-logloss:0.429817	validation_1-auc:0.825493	validation_1-error:0.229153	validation_1-logloss:0.500795
# [96]	validation_0-auc:0.901627	validation_0-error:0.170772	validation_0-logloss:0.428899	validation_1-auc:0.825848	validation_1-error:0.22981	validation_1-logloss:0.500186
# [97]	validation_0-auc:0.902161	validation_0-error:0.170772	validation_0-logloss:0.428009	validation_1-auc:0.825382	validation_1-error:0.231779	validation_1-logloss:0.500584
# [98]	validation_0-auc:0.902954	validation_0-error:0.170936	validation_0-logloss:0.427101	validation_1-auc:0.825456	validation_1-error:0.232436	validation_1-logloss:0.500124
# [99]	validation_0-auc:0.90319	validation_0-error:0.170936	validation_0-logloss:0.426092	validation_1-auc:0.825463	validation_1-error:0.231779	validation_1-logloss:0.499293
# [100]	validation_0-auc:0.903937	validation_0-error:0.169951	validation_0-logloss:0.425019	validation_1-auc:0.826318	validation_1-error:0.230466	validation_1-logloss:0.498458
# [101]	validation_0-auc:0.90428	validation_0-error:0.168966	validation_0-logloss:0.424055	validation_1-auc:0.827581	validation_1-error:0.231123	validation_1-logloss:0.496904
# [102]	validation_0-auc:0.904782	validation_0-error:0.169951	validation_0-logloss:0.423143	validation_1-auc:0.827285	validation_1-error:0.231123	validation_1-logloss:0.497116
# [103]	validation_0-auc:0.905364	validation_0-error:0.169787	validation_0-logloss:0.422217	validation_1-auc:0.827525	validation_1-error:0.230466	validation_1-logloss:0.497034
# [104]	validation_0-auc:0.905524	validation_0-error:0.170115	validation_0-logloss:0.421341	validation_1-auc:0.827441	validation_1-error:0.231123	validation_1-logloss:0.496989
# [105]	validation_0-auc:0.906071	validation_0-error:0.169294	validation_0-logloss:0.420416	validation_1-auc:0.82771	validation_1-error:0.22981	validation_1-logloss:0.49685
# [106]	validation_0-auc:0.906351	validation_0-error:0.168966	validation_0-logloss:0.419618	validation_1-auc:0.828199	validation_1-error:0.230466	validation_1-logloss:0.496222
# [107]	validation_0-auc:0.906405	validation_0-error:0.16913	validation_0-logloss:0.418768	validation_1-auc:0.828498	validation_1-error:0.230466	validation_1-logloss:0.495865
# [108]	validation_0-auc:0.90673	validation_0-error:0.166831	validation_0-logloss:0.41793	validation_1-auc:0.828323	validation_1-error:0.22981	validation_1-logloss:0.495965
# [109]	validation_0-auc:0.90726	validation_0-error:0.166831	validation_0-logloss:0.417203	validation_1-auc:0.828977	validation_1-error:0.22981	validation_1-logloss:0.495651
# [110]	validation_0-auc:0.907777	validation_0-error:0.167159	validation_0-logloss:0.41635	validation_1-auc:0.829086	validation_1-error:0.22981	validation_1-logloss:0.495476
# [111]	validation_0-auc:0.908154	validation_0-error:0.166338	validation_0-logloss:0.415504	validation_1-auc:0.828776	validation_1-error:0.230466	validation_1-logloss:0.495682
# [112]	validation_0-auc:0.908772	validation_0-error:0.165025	validation_0-logloss:0.414692	validation_1-auc:0.828857	validation_1-error:0.228496	validation_1-logloss:0.495583
# [113]	validation_0-auc:0.909169	validation_0-error:0.165353	validation_0-logloss:0.413918	validation_1-auc:0.828999	validation_1-error:0.229153	validation_1-logloss:0.495195
# [114]	validation_0-auc:0.909263	validation_0-error:0.164532	validation_0-logloss:0.413116	validation_1-auc:0.829261	validation_1-error:0.22784	validation_1-logloss:0.494484
# [115]	validation_0-auc:0.909828	validation_0-error:0.163711	validation_0-logloss:0.41226	validation_1-auc:0.830044	validation_1-error:0.223244	validation_1-logloss:0.493705
# [116]	validation_0-auc:0.910036	validation_0-error:0.162726	validation_0-logloss:0.411442	validation_1-auc:0.829777	validation_1-error:0.2239	validation_1-logloss:0.493675
# [117]	validation_0-auc:0.910152	validation_0-error:0.162233	validation_0-logloss:0.410685	validation_1-auc:0.830474	validation_1-error:0.222587	validation_1-logloss:0.492975
# [118]	validation_0-auc:0.910573	validation_0-error:0.161576	validation_0-logloss:0.409932	validation_1-auc:0.830468	validation_1-error:0.222587	validation_1-logloss:0.492759
# [119]	validation_0-auc:0.910935	validation_0-error:0.160755	validation_0-logloss:0.409159	validation_1-auc:0.831155	validation_1-error:0.221274	validation_1-logloss:0.492073
# [120]	validation_0-auc:0.911396	validation_0-error:0.159606	validation_0-logloss:0.408435	validation_1-auc:0.831175	validation_1-error:0.219304	validation_1-logloss:0.491697
# [121]	validation_0-auc:0.911605	validation_0-error:0.159113	validation_0-logloss:0.407639	validation_1-auc:0.831635	validation_1-error:0.219304	validation_1-logloss:0.491124
# [122]	validation_0-auc:0.911956	validation_0-error:0.158292	validation_0-logloss:0.406915	validation_1-auc:0.831865	validation_1-error:0.218647	validation_1-logloss:0.490889
# [123]	validation_0-auc:0.912399	validation_0-error:0.157964	validation_0-logloss:0.406151	validation_1-auc:0.832168	validation_1-error:0.219304	validation_1-logloss:0.490439
# [124]	validation_0-auc:0.912632	validation_0-error:0.157964	validation_0-logloss:0.405387	validation_1-auc:0.832555	validation_1-error:0.219961	validation_1-logloss:0.489797
# [125]	validation_0-auc:0.91303	validation_0-error:0.1578	validation_0-logloss:0.404677	validation_1-auc:0.83252	validation_1-error:0.219304	validation_1-logloss:0.489574
# [126]	validation_0-auc:0.913458	validation_0-error:0.157307	validation_0-logloss:0.403837	validation_1-auc:0.83233	validation_1-error:0.219961	validation_1-logloss:0.489486
# [127]	validation_0-auc:0.913918	validation_0-error:0.157964	validation_0-logloss:0.403189	validation_1-auc:0.832784	validation_1-error:0.219961	validation_1-logloss:0.488825
# [128]	validation_0-auc:0.914136	validation_0-error:0.157635	validation_0-logloss:0.402466	validation_1-auc:0.833221	validation_1-error:0.219304	validation_1-logloss:0.488716
# [129]	validation_0-auc:0.914461	validation_0-error:0.158292	validation_0-logloss:0.401702	validation_1-auc:0.833498	validation_1-error:0.221274	validation_1-logloss:0.48847
# [130]	validation_0-auc:0.914804	validation_0-error:0.157307	validation_0-logloss:0.400895	validation_1-auc:0.833124	validation_1-error:0.220617	validation_1-logloss:0.488469
# [131]	validation_0-auc:0.915104	validation_0-error:0.157635	validation_0-logloss:0.400234	validation_1-auc:0.832841	validation_1-error:0.220617	validation_1-logloss:0.489051
# [132]	validation_0-auc:0.915408	validation_0-error:0.157635	validation_0-logloss:0.399569	validation_1-auc:0.832848	validation_1-error:0.22193	validation_1-logloss:0.489035
# [133]	validation_0-auc:0.915589	validation_0-error:0.157471	validation_0-logloss:0.398853	validation_1-auc:0.832467	validation_1-error:0.220617	validation_1-logloss:0.488975
# [134]	validation_0-auc:0.916129	validation_0-error:0.156486	validation_0-logloss:0.398151	validation_1-auc:0.83284	validation_1-error:0.220617	validation_1-logloss:0.488451
# [135]	validation_0-auc:0.916362	validation_0-error:0.156322	validation_0-logloss:0.397494	validation_1-auc:0.833059	validation_1-error:0.220617	validation_1-logloss:0.488183
# [136]	validation_0-auc:0.916577	validation_0-error:0.156814	validation_0-logloss:0.396835	validation_1-auc:0.833058	validation_1-error:0.221274	validation_1-logloss:0.487951
# [137]	validation_0-auc:0.916874	validation_0-error:0.156158	validation_0-logloss:0.396152	validation_1-auc:0.83261	validation_1-error:0.222587	validation_1-logloss:0.488217
# [138]	validation_0-auc:0.917091	validation_0-error:0.156322	validation_0-logloss:0.395455	validation_1-auc:0.832125	validation_1-error:0.22193	validation_1-logloss:0.488366
# [139]	validation_0-auc:0.91741	validation_0-error:0.155993	validation_0-logloss:0.39476	validation_1-auc:0.832255	validation_1-error:0.218647	validation_1-logloss:0.488309
# [140]	validation_0-auc:0.91774	validation_0-error:0.155501	validation_0-logloss:0.394126	validation_1-auc:0.832537	validation_1-error:0.218647	validation_1-logloss:0.487695
# [141]	validation_0-auc:0.918121	validation_0-error:0.155172	validation_0-logloss:0.393557	validation_1-auc:0.832598	validation_1-error:0.219961	validation_1-logloss:0.487411
# [142]	validation_0-auc:0.918078	validation_0-error:0.15468	validation_0-logloss:0.393032	validation_1-auc:0.832747	validation_1-error:0.223244	validation_1-logloss:0.486989
# [143]	validation_0-auc:0.918297	validation_0-error:0.155008	validation_0-logloss:0.392409	validation_1-auc:0.83284	validation_1-error:0.222587	validation_1-logloss:0.486466
# [144]	validation_0-auc:0.918574	validation_0-error:0.154516	validation_0-logloss:0.391771	validation_1-auc:0.832421	validation_1-error:0.222587	validation_1-logloss:0.486796
# [145]	validation_0-auc:0.918512	validation_0-error:0.154187	validation_0-logloss:0.391132	validation_1-auc:0.831709	validation_1-error:0.225213	validation_1-logloss:0.487766
# [146]	validation_0-auc:0.918753	validation_0-error:0.154187	validation_0-logloss:0.390521	validation_1-auc:0.832057	validation_1-error:0.225213	validation_1-logloss:0.487429
# [147]	validation_0-auc:0.918748	validation_0-error:0.154516	validation_0-logloss:0.390012	validation_1-auc:0.832253	validation_1-error:0.2239	validation_1-logloss:0.487559
# [148]	validation_0-auc:0.918957	validation_0-error:0.155172	validation_0-logloss:0.389347	validation_1-auc:0.832125	validation_1-error:0.222587	validation_1-logloss:0.487404
# [149]	validation_0-auc:0.919176	validation_0-error:0.15468	validation_0-logloss:0.388739	validation_1-auc:0.83228	validation_1-error:0.222587	validation_1-logloss:0.487083
# [150]	validation_0-auc:0.919916	validation_0-error:0.154351	validation_0-logloss:0.387852	validation_1-auc:0.83246	validation_1-error:0.223244	validation_1-logloss:0.48722
# [151]	validation_0-auc:0.920079	validation_0-error:0.154351	validation_0-logloss:0.387179	validation_1-auc:0.832159	validation_1-error:0.224557	validation_1-logloss:0.487626
# [152]	validation_0-auc:0.92053	validation_0-error:0.154351	validation_0-logloss:0.386487	validation_1-auc:0.831899	validation_1-error:0.22193	validation_1-logloss:0.487818
# [153]	validation_0-auc:0.920702	validation_0-error:0.153859	validation_0-logloss:0.385838	validation_1-auc:0.832314	validation_1-error:0.221274	validation_1-logloss:0.487366
# [154]	validation_0-auc:0.920849	validation_0-error:0.153202	validation_0-logloss:0.385276	validation_1-auc:0.831882	validation_1-error:0.220617	validation_1-logloss:0.487743
# [155]	validation_0-auc:0.921317	validation_0-error:0.152874	validation_0-logloss:0.384591	validation_1-auc:0.832023	validation_1-error:0.219961	validation_1-logloss:0.487537
# [156]	validation_0-auc:0.921541	validation_0-error:0.152053	validation_0-logloss:0.384003	validation_1-auc:0.831895	validation_1-error:0.22193	validation_1-logloss:0.487819
# [157]	validation_0-auc:0.921493	validation_0-error:0.151888	validation_0-logloss:0.383499	validation_1-auc:0.832117	validation_1-error:0.223244	validation_1-logloss:0.487845
# [158]	validation_0-auc:0.92175	validation_0-error:0.151724	validation_0-logloss:0.382905	validation_1-auc:0.832346	validation_1-error:0.222587	validation_1-logloss:0.487537
# [159]	validation_0-auc:0.921973	validation_0-error:0.150903	validation_0-logloss:0.382282	validation_1-auc:0.831918	validation_1-error:0.224557	validation_1-logloss:0.487557
# [160]	validation_0-auc:0.922414	validation_0-error:0.149589	validation_0-logloss:0.381469	validation_1-auc:0.831825	validation_1-error:0.223244	validation_1-logloss:0.487147
# [161]	validation_0-auc:0.922752	validation_0-error:0.148933	validation_0-logloss:0.380919	validation_1-auc:0.832294	validation_1-error:0.221274	validation_1-logloss:0.486858
# [162]	validation_0-auc:0.922947	validation_0-error:0.148768	validation_0-logloss:0.380381	validation_1-auc:0.832472	validation_1-error:0.220617	validation_1-logloss:0.486596
# [163]	validation_0-auc:0.923174	validation_0-error:0.148768	validation_0-logloss:0.379839	validation_1-auc:0.831901	validation_1-error:0.220617	validation_1-logloss:0.487065
# Stopping. Best iteration:
# [143]	validation_0-auc:0.918297	validation_0-error:0.155008	validation_0-logloss:0.392409	validation_1-auc:0.83284	validation_1-error:0.222587	validation_1-logloss:0.486466
#
# Accuracy: 77.74 %
# F1-score: 0.71
# Confusion matrix:
#  [[761 113]
#  [226 423]]

# %%
# retrieve performance metrics
results = model.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Validaion')
ax.legend()
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# plot classification error
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Validation')
ax.legend()
plt.xlabel('Epochs')
plt.ylabel('Classification Error')
plt.title('XGBoost Classification Error')
plt.show()
# plot auc
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['auc'], label='Train')
ax.plot(x_axis, results['validation_1']['auc'], label='Validation')
ax.legend()
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('XGBoost AUC')
plt.show()

# %%
# retrieve performance metrics
results = model.evals_result()
epochs = len(results['validation_0']['auc'])
x_axis = range(0, epochs)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,5))

# plot auc
ax1.plot(x_axis, results['validation_0']['auc'], label='Train')
ax1.plot(x_axis, results['validation_1']['auc'], label='Validation')
ax1.set_title("XGBoost AUC")
ax1.legend()

# plot log loss
ax2.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax2.plot(x_axis, results['validation_1']['logloss'], label='Validation')
ax2.set_title("XGBoost Log Loss")
ax2.legend()

# plot classification error
ax3.plot(x_axis, results['validation_0']['error'], label='Train')
ax3.plot(x_axis, results['validation_1']['error'], label='Validation')
ax3.set_title("XGBoost Classification Error")
ax3.legend()

plt.show()

# %%
fpr, tpr, _ = roc_curve(y_val, y_val_pred)
auc_score = auc(fpr, tpr)

plt.figure()
plt.title('ROC Curve')
plt.plot(fpr, tpr, marker='.', label='AUC = {:.2f}'.format(auc_score))

# it's helpful to add a diagonal to indicate where chance 
# scores lie (i.e. just flipping a coin)
plt.plot([0,1],[0,1],'r--')

plt.xlim([-0.1,1.1])
plt.ylim([-0.1,1.1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend(loc='lower right')
plt.show()

# %%
df_test = pd.read_csv('test.csv')
df_sub = pd.read_csv('sample_submission.csv')

X_test = vect.transform(df_test['text'])
df_sub['target'] = model.predict(X_test)
df_sub.to_csv('submission.csv', index=False)
df_sub.tail(3)
# Out:
#          id  target
# 3260  10868       0
# 3261  10874       0
# 3262  10875       0

# %%
# submit
# !kaggle competitions submit -c nlp-getting-started -f submission.csv -m "xgboost"
# Out:
# 100%|██████████████████████████████████████| 22.2k/22.2k [00:03<00:00, 6.12kB/s]
# Successfully submitted to Real or Not? NLP with Disaster Tweets

# %%
# score on LB
# !kaggle competitions submissions -c nlp-getting-started
# Out:
# fileName        date                 description           status    publicScore  privateScore
# --------------  -------------------  --------------------  --------  -----------  ------------
# submission.csv  2020-04-09 18:22:16  xgboost               complete  0.68916      None
# submission.csv  2020-04-06 18:53:51  ys02                  complete  0.67280      None
# submission.csv  2020-04-06 17:46:16  ys01                  complete  0.66053      None
# submission.csv  2020-04-05 13:20:07  ys01                  complete  0.71267      None
# submission.csv  2020-04-04 22:23:58  ys01                  complete  0.71472      None
# submission.csv  2020-04-04 08:59:33  ys02                  complete  0.70347      None
# submission.csv  2020-04-04 06:18:21  ys01                  complete  0.70347      None
# submission.csv  2020-03-31 22:57:29  ys02                  complete  0.78220      None
# submission.csv  2020-03-31 22:49:47  ys01                  complete  0.76584      None
# submission.csv  2020-03-30 22:33:41  ys02                  complete  0.79141      None
# submission.csv  2020-03-30 21:01:21  ys01                  complete  0.78732      None
# submission.csv  2020-03-23 12:27:31  ys-20200323-4         complete  0.78220      None
# submission.csv  2020-03-23 08:59:13  ys-20200323-3         complete  0.78732      None
# submission.csv  2020-03-23 02:05:32  ys-20200323-2         complete  0.79243      None
# submission.csv  2020-03-23 01:53:34  ys-20200323           complete  0.77402      None
# submission.csv  2020-03-02 18:41:51  sub-yaun-20200302-03  complete  0.73006      None
# submission.csv  2020-03-02 18:32:05  sub-yaun-20200302-02  complete  0.67586      None
# submission.csv  2020-03-02 18:26:13  ysun-20200302-01      complete  0.00000      None
# submission.csv  2020-02-27 20:30:31  sub-ysun-20200227-02  complete  0.77505      None
# submission.csv  2020-02-26 23:50:24  sub-ysun-20200227     complete  0.72085      None
